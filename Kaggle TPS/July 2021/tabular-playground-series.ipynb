# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sb
import missingno

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from xgboost import XGBRegressor

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
url_train = "../input/tabular-playground-series-jul-2021/train.csv"
data_train = pd.read_csv(url_train)
url_test = "../input/tabular-playground-series-jul-2021/test.csv"
data_test = pd.read_csv(url_test)
#print(dataset.shape)
#print(dataset.describe())
#dataset.hist()
#pyplot.show()

# %%
data_train

# %%
data_test

# %%
data_train.describe()

# %%
data_test.loc[:, "absolute_humidity"].describe()

# %%
data_test.drop(columns = 'absolute_humidity')

# %%
correlation = data_train.corr()
correlation

# %%
sb.set(rc={"figure.figsize":(10,8)})
sb.heatmap(correlation, annot = True)

# %%
data_train.var()

# %%
data_train.std()

# %%
data_train.hist()

# %%
#data_train= data_train.drop(columns = ['absolute_humidity'])
#data_test = data_test.drop(columns = ['absolute_humidity'])
data_test

# %%
data_test.columns

# %%
labels = ['target_carbon_monoxide', 'target_benzene', 'target_nitrogen_oxides']
data_train2 = data_train.drop(columns = labels)

# %%
target_carbon_monoxide = data_train['target_carbon_monoxide']
target_benzene = data_train['target_benzene']
target_nitrogen_oxides = data_train['target_nitrogen_oxides']
target_carbon_monoxide.describe()

# %%
data_train2.drop(columns = 'date_time', inplace = True)

# %%
data_test.drop(columns = 'date_time', inplace = True)

# %%
data_train2.info(), data_test.info()

# %%
model = XGBRegressor( learning_rate=0.05, n_estimators=500, subsample=1.0,alpha=0.9)
model.fit(data_train2, target_carbon_monoxide)
sample_submission['target_carbon_monoxide'] = model.predict(data_test)

model = XGBRegressor( learning_rate=0.05, n_estimators=500, subsample=1.0, alpha=0.9)
model.fit(data_train2, target_benzene)
sample_submission['target_benzene'] = model.predict(data_test)

model = XGBRegressor( learning_rate=0.05, n_estimators=500, subsample=1.0, alpha=0.9)
model.fit(data_train2, target_nitrogen_oxides)
sample_submission['target_nitrogen_oxides'] = model.predict(data_test)
